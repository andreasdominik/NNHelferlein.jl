# %% [markdown]
# # Convolutional Autoencoder
#
# The notebook shows how simple autoencoder types can be designed with Knet and NNHelferlein.
# The small example images are in the NNHelderlein data-directory.

# %%
using Knet
using NNHelferlein
using Images

# %% [markdown]
# ### Data
# Load images from directory, flatten the 64x64x3 tensors to a 1-D-vecor and
# build a matrix with 12288 rows (= RGB-values of all pixels) and
# 4 columns (= number of pictures).
#
# Training data must be flattened because each image is represented by a 1D-vector
# in the perceptron.
# Final training tensor is (num-pixels x 3) x (num images):

# %%
d = joinpath(NNHelferlein.DATA_DIR, "Images64")
imgs = [load(joinpath(d, i)) for i in readdir(d) if occursin("png", i)]
# Out:
# 5-element Vector{Matrix{RGB{N0f8}}}:
#  [RGB{N0f8}(0.435,0.647,0.675) RGB{N0f8}(0.435,0.643,0.675) … RGB{N0f8}(0.741,0.812,0.784) RGB{N0f8}(0.612,0.737,0.737); RGB{N0f8}(0.314,0.573,0.62) RGB{N0f8}(0.302,0.573,0.616) … RGB{N0f8}(0.533,0.698,0.702) RGB{N0f8}(0.455,0.655,0.678); … ; RGB{N0f8}(0.161,0.282,0.325) RGB{N0f8}(0.176,0.286,0.333) … RGB{N0f8}(0.573,0.643,0.671) RGB{N0f8}(0.667,0.729,0.761); RGB{N0f8}(0.176,0.302,0.341) RGB{N0f8}(0.169,0.282,0.325) … RGB{N0f8}(0.439,0.537,0.565) RGB{N0f8}(0.475,0.561,0.596)]
#  [RGB{N0f8}(0.439,0.361,0.259) RGB{N0f8}(0.439,0.349,0.247) … RGB{N0f8}(0.49,0.478,0.459) RGB{N0f8}(0.486,0.471,0.455); RGB{N0f8}(0.471,0.392,0.282) RGB{N0f8}(0.471,0.376,0.278) … RGB{N0f8}(0.486,0.471,0.451) RGB{N0f8}(0.478,0.467,0.447); … ; RGB{N0f8}(0.565,0.42,0.518) RGB{N0f8}(0.867,0.796,0.886) … RGB{N0f8}(0.969,0.867,0.984) RGB{N0f8}(0.965,0.867,0.984); RGB{N0f8}(0.541,0.384,0.486) RGB{N0f8}(0.918,0.847,0.945) … RGB{N0f8}(0.965,0.851,0.969) RGB{N0f8}(0.965,0.867,0.984)]
#  [RGB{N0f8}(0.369,0.349,0.373) RGB{N0f8}(0.376,0.333,0.322) … RGB{N0f8}(0.482,0.263,0.224) RGB{N0f8}(0.459,0.337,0.314); RGB{N0f8}(0.373,0.353,0.376) RGB{N0f8}(0.376,0.337,0.325) … RGB{N0f8}(0.478,0.278,0.235) RGB{N0f8}(0.459,0.345,0.318); … ; RGB{N0f8}(0.416,0.325,0.439) RGB{N0f8}(0.408,0.329,0.439) … RGB{N0f8}(0.439,0.376,0.373) RGB{N0f8}(0.439,0.376,0.369); RGB{N0f8}(0.408,0.318,0.431) RGB{N0f8}(0.404,0.325,0.435) … RGB{N0f8}(0.439,0.376,0.376) RGB{N0f8}(0.439,0.376,0.373)]
#  [RGB{N0f8}(0.949,0.949,0.949) RGB{N0f8}(0.953,0.953,0.953) … RGB{N0f8}(0.984,0.984,0.984) RGB{N0f8}(0.984,0.984,0.984); RGB{N0f8}(0.949,0.949,0.949) RGB{N0f8}(0.953,0.953,0.953) … RGB{N0f8}(0.984,0.984,0.984) RGB{N0f8}(0.984,0.984,0.984); … ; RGB{N0f8}(0.906,0.906,0.906) RGB{N0f8}(0.91,0.91,0.91) … RGB{N0f8}(0.925,0.925,0.925) RGB{N0f8}(0.922,0.922,0.922); RGB{N0f8}(0.906,0.906,0.906) RGB{N0f8}(0.906,0.906,0.906) … RGB{N0f8}(0.922,0.922,0.922) RGB{N0f8}(0.922,0.922,0.922)]
#  [RGB{N0f8}(0.267,0.525,0.973) RGB{N0f8}(0.271,0.529,0.973) … RGB{N0f8}(0.259,0.518,0.949) RGB{N0f8}(0.255,0.514,0.945); RGB{N0f8}(0.282,0.525,0.976) RGB{N0f8}(0.286,0.525,0.976) … RGB{N0f8}(0.263,0.522,0.953) RGB{N0f8}(0.259,0.518,0.953); … ; RGB{N0f8}(0.761,0.643,0.545) RGB{N0f8}(0.757,0.671,0.573) … RGB{N0f8}(0.784,0.757,0.69) RGB{N0f8}(0.808,0.761,0.761); RGB{N0f8}(0.753,0.663,0.569) RGB{N0f8}(0.816,0.71,0.655) … RGB{N0f8}(0.745,0.694,0.608) RGB{N0f8}(0.792,0.733,0.675)]

# %% [markdown]
# ## The Autoencoder
#
# For the convolutional autoencoder the decoder output is
# cropped to the original image size before loss calculation.

# %%
struct CnnAE <: DNN
    layers
    CnnAE(e,d) = new([e,d])
end

function (ae::CnnAE)(x)
    
    # encode:
    #
    size_in = size(x)
    x = ae.layers[1](x)
    
    # decode:
    #
    x = ae.layers[2](x)
    x = crop_array(x, size_in)
    return x
end

# square loss:
#
(ae::CnnAE)(x, y) = sum(abs2, ae(x) .- y)

# %%
encoder = Chain(
            Conv(5,5,3,32; padding=2),
            Pool(),
            Conv(5,5,32,16; padding=2),
            Pool(),
            Conv(5,5,16,8; padding=2),
            Pool())

decoder = Chain(
            DeConv(5,5,8,16; stride=2),
            DeConv(5,5,16,32; stride=2),
            DeConv(5,5,32,3; stride=2))
# Out:
# Chain((DeConv(P(KnetArray{Float32, 4}(5,5,16,8)), P(KnetArray{Float32, 4}(1,1,16,1)), Knet.Ops20.relu, Base.Pairs(:stride => 2)), DeConv(P(KnetArray{Float32, 4}(5,5,32,16)), P(KnetArray{Float32, 4}(1,1,32,1)), Knet.Ops20.relu, Base.Pairs(:stride => 2)), DeConv(P(KnetArray{Float32, 4}(5,5,3,32)), P(KnetArray{Float32, 4}(1,1,3,1)), Knet.Ops20.relu, Base.Pairs(:stride => 2))))

# %%
cae = CnnAE(encoder, decoder)
print_network(cae)
# Out:
# Neural network summary:
# CnnAE with 2 layers,                                             36907 params
# Details:
#
#     Chain with 6 layers,                                         18456 params
#
#         Conv layer 3 → 32 (5,5) [:padding => 2] with relu,        2432 params
#         Pool layer,                                                  0 params
#         Conv layer 32 → 16 (5,5) [:padding => 2] with relu,      12816 params
#         Pool layer,                                                  0 params
#         Conv layer 16 → 8 (5,5) [:padding => 2] with relu,        3208 params
#         Pool layer,                                                  0 params
#
#     Chain with 3 layers,                                         18451 params
#
#         DeConv layer 8 → 16 (5,5) [:stride => 2] with relu,       3216 params
#         DeConv layer 16 → 32 (5,5) [:stride => 2] with relu,      12832 params
#         DeConv layer 32 → 3 (5,5) [:stride => 2] with relu,       2403 params
#
#
# Total number of layers: 9
# Total number of parameters: 36907
# 9

# %% [markdown]
# Training data must be provided as 4D-array for the CNN (image hight, image width, rgb, num images):

# %%
trn = cat((image2array.(imgs))..., dims=4)
trn = convert2KnetArray(trn)
size(trn)
# Out:
# (64, 64, 3, 5)

# %%
@show y = size(cae(trn))
@show loss = cae(trn, trn)
# Out:
# y = size(cae(trn)) = (64, 64, 3, 5)
# loss = cae(trn, trn) = 21514.627f0
# 21514.627f0

# %% [markdown]
# Minibatches and train until the images are reconstructed:

# %%
mbs = minibatch(trn, trn, 5)
# Out:
# 1-element Knet.Train20.Data{Tuple{KnetArray{Float32}, KnetArray{Float32}}}

# %%
tb_train!(cae, Adam, mbs, epochs=10000, lr=0.0001)
# Out:
# Training 10000 epochs with 1 minibatches/epoch
# Evaluation is performed every 1 minibatches (with 1 mbs).
# Watch the progress with TensorBoard at: /home/andreas/.julia/dev/NNHelferlein/examples/logs/run/2021-12-20T10-38-20
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:56
# Training finished with:
# Training loss:       57.801429748535156
# CnnAE(Chain[Chain((Conv(P(KnetArray{Float32, 4}(5,5,3,32)), P(KnetArray{Float32, 4}(1,1,32,1)), Knet.Ops20.relu, Base.Pairs(:padding => 2)), Pool(Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}()), Conv(P(KnetArray{Float32, 4}(5,5,32,16)), P(KnetArray{Float32, 4}(1,1,16,1)), Knet.Ops20.relu, Base.Pairs(:padding => 2)), Pool(Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}()), Conv(P(KnetArray{Float32, 4}(5,5,16,8)), P(KnetArray{Float32, 4}(1,1,8,1)), Knet.Ops20.relu, Base.Pairs(:padding => 2)), Pool(Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}()))), Chain((DeConv(P(KnetArray{Float32, 4}(5,5,16,8)), P(KnetArray{Float32, 4}(1,1,16,1)), Knet.Ops20.relu, Base.Pairs(:stride => 2)), DeConv(P(KnetArray{Float32, 4}(5,5,32,16)), P(KnetArray{Float32, 4}(1,1,32,1)), Knet.Ops20.relu, Base.Pairs(:stride => 2)), DeConv(P(KnetArray{Float32, 4}(5,5,3,32)), P(KnetArray{Float32, 4}(1,1,3,1)), Knet.Ops20.relu, Base.Pairs(:stride => 2))))])

# %%
y = cae(trn)
[array2image(y[:,:,:,i]) for i in 1:size(y)[end]]
# Out:
# 5-element Vector{Base.ReinterpretArray{RGB{Float32}, 2, Float32, Array{Float32, 3}, true}}:
#  [RGB{Float32}(0.42094317f0,0.6258669f0,0.69872904f0) RGB{Float32}(0.40060392f0,0.6070512f0,0.66500753f0) … RGB{Float32}(0.6980603f0,0.78779584f0,0.7880836f0) RGB{Float32}(0.6408947f0,0.7484099f0,0.77004635f0); RGB{Float32}(0.34146267f0,0.5563176f0,0.62975013f0) RGB{Float32}(0.28666142f0,0.5194706f0,0.6040464f0) … RGB{Float32}(0.55581397f0,0.6530933f0,0.68207985f0) RGB{Float32}(0.5485187f0,0.6573222f0,0.7076236f0); … ; RGB{Float32}(0.13748723f0,0.2157979f0,0.29808477f0) RGB{Float32}(0.15290996f0,0.2392705f0,0.30922386f0) … RGB{Float32}(0.5402448f0,0.6450521f0,0.6718401f0) RGB{Float32}(0.6608297f0,0.73512566f0,0.7461864f0); RGB{Float32}(0.1829951f0,0.27429637f0,0.34825575f0) RGB{Float32}(0.20519695f0,0.30078736f0,0.3619958f0) … RGB{Float32}(0.417169f0,0.5362562f0,0.5327367f0) RGB{Float32}(0.48461327f0,0.5965178f0,0.56504405f0)]
#  [RGB{Float32}(0.487125f0,0.41779572f0,0.3323463f0) RGB{Float32}(0.43664247f0,0.37988472f0,0.2702038f0) … RGB{Float32}(0.48717278f0,0.48207515f0,0.46178392f0) RGB{Float32}(0.48602888f0,0.48910853f0,0.48389038f0); RGB{Float32}(0.4669137f0,0.4000882f0,0.29485384f0) RGB{Float32}(0.42967132f0,0.3708893f0,0.25369713f0) … RGB{Float32}(0.4801582f0,0.46704268f0,0.4540628f0) RGB{Float32}(0.4590084f0,0.44590837f0,0.4366938f0); … ; RGB{Float32}(0.5647151f0,0.44845194f0,0.48296627f0) RGB{Float32}(0.881005f0,0.776677f0,0.86665726f0) … RGB{Float32}(0.98121285f0,0.86651254f0,0.98748267f0) RGB{Float32}(0.9857827f0,0.8829292f0,1.0140411f0); RGB{Float32}(0.5415683f0,0.45566705f0,0.49941993f0) RGB{Float32}(0.9109214f0,0.81569576f0,0.93131256f0) … RGB{Float32}(0.941776f0,0.8607984f0,0.9971849f0) RGB{Float32}(0.91800904f0,0.83825743f0,0.9943435f0)]
#  [RGB{Float32}(0.370304f0,0.32485113f0,0.35053962f0) RGB{Float32}(0.4108208f0,0.33778927f0,0.36172625f0) … RGB{Float32}(0.48710814f0,0.27214298f0,0.20502517f0) RGB{Float32}(0.503453f0,0.34592363f0,0.3015789f0); RGB{Float32}(0.41612312f0,0.3599248f0,0.36011198f0) RGB{Float32}(0.4104201f0,0.32900435f0,0.34800252f0) … RGB{Float32}(0.47328612f0,0.26154247f0,0.21959779f0) RGB{Float32}(0.46742532f0,0.30824897f0,0.2860141f0); … ; RGB{Float32}(0.4163598f0,0.3553839f0,0.44520095f0) RGB{Float32}(0.41449144f0,0.34186423f0,0.4301656f0) … RGB{Float32}(0.41698793f0,0.37016258f0,0.41148698f0) RGB{Float32}(0.39039198f0,0.3407112f0,0.36484596f0); RGB{Float32}(0.36493385f0,0.33216432f0,0.4070534f0) RGB{Float32}(0.37906116f0,0.33471668f0,0.41722068f0) … RGB{Float32}(0.40607166f0,0.3571307f0,0.40527228f0) RGB{Float32}(0.4226403f0,0.37717536f0,0.41643947f0)]
#  [RGB{Float32}(0.9416067f0,0.9449082f0,0.9388168f0) RGB{Float32}(0.95389575f0,0.95997787f0,0.94250846f0) … RGB{Float32}(0.98221415f0,0.9907447f0,0.9806251f0) RGB{Float32}(0.95715344f0,0.9825603f0,1.0023792f0); RGB{Float32}(0.935553f0,0.9401371f0,0.951535f0) RGB{Float32}(0.9634108f0,0.9712588f0,0.9876952f0) … RGB{Float32}(0.95790035f0,0.96685463f0,0.98676383f0) RGB{Float32}(0.97083634f0,0.97070146f0,0.99633044f0); … ; RGB{Float32}(0.91945404f0,0.9023189f0,0.9367129f0) RGB{Float32}(0.9081716f0,0.88152254f0,0.90275687f0) … RGB{Float32}(0.935723f0,0.94109946f0,0.95073414f0) RGB{Float32}(0.94486606f0,0.91578186f0,0.9082896f0); RGB{Float32}(0.88352674f0,0.90899825f0,0.918439f0) RGB{Float32}(0.88961387f0,0.902151f0,0.9176599f0) … RGB{Float32}(0.90261596f0,0.8878143f0,0.91447383f0) RGB{Float32}(0.9681496f0,0.9336308f0,0.95766735f0)]
#  [RGB{Float32}(0.30419362f0,0.5879501f0,0.98528266f0) RGB{Float32}(0.296679f0,0.544056f0,0.9141905f0) … RGB{Float32}(0.28470737f0,0.53502065f0,0.930297f0) RGB{Float32}(0.29286525f0,0.52998024f0,0.9135955f0); RGB{Float32}(0.27205738f0,0.5463656f0,0.9482323f0) RGB{Float32}(0.27626723f0,0.5407951f0,0.95877206f0) … RGB{Float32}(0.27477303f0,0.5358729f0,0.9218916f0) RGB{Float32}(0.28221002f0,0.52459323f0,0.8970517f0); … ; RGB{Float32}(0.7763867f0,0.67370737f0,0.5534409f0) RGB{Float32}(0.76743317f0,0.66950953f0,0.5822971f0) … RGB{Float32}(0.7505712f0,0.70018274f0,0.65964144f0) RGB{Float32}(0.8090127f0,0.7443579f0,0.7012155f0); RGB{Float32}(0.7234353f0,0.6490791f0,0.54018825f0) RGB{Float32}(0.8447392f0,0.7464349f0,0.66249526f0) … RGB{Float32}(0.77397496f0,0.6922274f0,0.63232666f0) RGB{Float32}(0.80809116f0,0.73558223f0,0.6789459f0)]
