# %% [markdown]
# # Variational Autoencoder

# %%
using Knet
using NNHelferlein, CUDA
using Images

# %% [markdown]
# ### Data
# Load images from directory, flatten the 64x64x3 tensors to a vecor and
# build a matrix with 12288 rows (= RGB-values of all pixels) and
# 5 columns (= number of pictures).

# %%
d = joinpath(NNHelferlein.DATA_DIR, "Images64")
imgs = [load(joinpath(d, i)) for i in readdir(d) if occursin("png", i)]
# Out:
# 5-element Vector{Matrix{RGB{N0f8}}}:
#  [RGB{N0f8}(0.435,0.647,0.675) RGB{N0f8}(0.435,0.643,0.675) … RGB{N0f8}(0.741,0.812,0.784) RGB{N0f8}(0.612,0.737,0.737); RGB{N0f8}(0.314,0.573,0.62) RGB{N0f8}(0.302,0.573,0.616) … RGB{N0f8}(0.533,0.698,0.702) RGB{N0f8}(0.455,0.655,0.678); … ; RGB{N0f8}(0.161,0.282,0.325) RGB{N0f8}(0.176,0.286,0.333) … RGB{N0f8}(0.573,0.643,0.671) RGB{N0f8}(0.667,0.729,0.761); RGB{N0f8}(0.176,0.302,0.341) RGB{N0f8}(0.169,0.282,0.325) … RGB{N0f8}(0.439,0.537,0.565) RGB{N0f8}(0.475,0.561,0.596)]
#  [RGB{N0f8}(0.439,0.361,0.259) RGB{N0f8}(0.439,0.349,0.247) … RGB{N0f8}(0.49,0.478,0.459) RGB{N0f8}(0.486,0.471,0.455); RGB{N0f8}(0.471,0.392,0.282) RGB{N0f8}(0.471,0.376,0.278) … RGB{N0f8}(0.486,0.471,0.451) RGB{N0f8}(0.478,0.467,0.447); … ; RGB{N0f8}(0.565,0.42,0.518) RGB{N0f8}(0.867,0.796,0.886) … RGB{N0f8}(0.969,0.867,0.984) RGB{N0f8}(0.965,0.867,0.984); RGB{N0f8}(0.541,0.384,0.486) RGB{N0f8}(0.918,0.847,0.945) … RGB{N0f8}(0.965,0.851,0.969) RGB{N0f8}(0.965,0.867,0.984)]
#  [RGB{N0f8}(0.369,0.349,0.373) RGB{N0f8}(0.376,0.333,0.322) … RGB{N0f8}(0.482,0.263,0.224) RGB{N0f8}(0.459,0.337,0.314); RGB{N0f8}(0.373,0.353,0.376) RGB{N0f8}(0.376,0.337,0.325) … RGB{N0f8}(0.478,0.278,0.235) RGB{N0f8}(0.459,0.345,0.318); … ; RGB{N0f8}(0.416,0.325,0.439) RGB{N0f8}(0.408,0.329,0.439) … RGB{N0f8}(0.439,0.376,0.373) RGB{N0f8}(0.439,0.376,0.369); RGB{N0f8}(0.408,0.318,0.431) RGB{N0f8}(0.404,0.325,0.435) … RGB{N0f8}(0.439,0.376,0.376) RGB{N0f8}(0.439,0.376,0.373)]
#  [RGB{N0f8}(0.949,0.949,0.949) RGB{N0f8}(0.953,0.953,0.953) … RGB{N0f8}(0.984,0.984,0.984) RGB{N0f8}(0.984,0.984,0.984); RGB{N0f8}(0.949,0.949,0.949) RGB{N0f8}(0.953,0.953,0.953) … RGB{N0f8}(0.984,0.984,0.984) RGB{N0f8}(0.984,0.984,0.984); … ; RGB{N0f8}(0.906,0.906,0.906) RGB{N0f8}(0.91,0.91,0.91) … RGB{N0f8}(0.925,0.925,0.925) RGB{N0f8}(0.922,0.922,0.922); RGB{N0f8}(0.906,0.906,0.906) RGB{N0f8}(0.906,0.906,0.906) … RGB{N0f8}(0.922,0.922,0.922) RGB{N0f8}(0.922,0.922,0.922)]
#  [RGB{N0f8}(0.267,0.525,0.973) RGB{N0f8}(0.271,0.529,0.973) … RGB{N0f8}(0.259,0.518,0.949) RGB{N0f8}(0.255,0.514,0.945); RGB{N0f8}(0.282,0.525,0.976) RGB{N0f8}(0.286,0.525,0.976) … RGB{N0f8}(0.263,0.522,0.953) RGB{N0f8}(0.259,0.518,0.953); … ; RGB{N0f8}(0.761,0.643,0.545) RGB{N0f8}(0.757,0.671,0.573) … RGB{N0f8}(0.784,0.757,0.69) RGB{N0f8}(0.808,0.761,0.761); RGB{N0f8}(0.753,0.663,0.569) RGB{N0f8}(0.816,0.71,0.655) … RGB{N0f8}(0.745,0.694,0.608) RGB{N0f8}(0.792,0.733,0.675)]

# %%
trn = hcat(vec.(image2array.(imgs))...)
trn = convert2KnetArray(trn)
size(trn)
# Out:
# (12288, 5)

# %% [markdown]
# This is how the vectors can be transformed into pictures again (array2image() is from the NNHelferlein-API):

# %%
array2image(reshape(trn[:,1], 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.435294,0.647059,0.67451)   …  RGB{Float32}(0.611765,0.737255,0.737255)
#  RGB{Float32}(0.313726,0.572549,0.619608)     RGB{Float32}(0.454902,0.654902,0.678431)
#  RGB{Float32}(0.305882,0.580392,0.623529)     RGB{Float32}(0.341176,0.607843,0.654902)
#  RGB{Float32}(0.345098,0.603922,0.639216)     RGB{Float32}(0.305882,0.596078,0.639216)
#  RGB{Float32}(0.411765,0.65098,0.686275)      RGB{Float32}(0.290196,0.584314,0.631373)
#  RGB{Float32}(0.498039,0.698039,0.717647)  …  RGB{Float32}(0.32549,0.6,0.643137)
#  RGB{Float32}(0.6,0.772549,0.772549)          RGB{Float32}(0.411765,0.635294,0.67451)
#  RGB{Float32}(0.701961,0.823529,0.815686)     RGB{Float32}(0.392157,0.619608,0.654902)
#  RGB{Float32}(0.760784,0.854902,0.843137)     RGB{Float32}(0.580392,0.72549,0.713726)
#  RGB{Float32}(0.815686,0.898039,0.87451)      RGB{Float32}(0.764706,0.823529,0.760784)
#  RGB{Float32}(0.886275,0.933333,0.913725)  …  RGB{Float32}(0.686275,0.768627,0.729412)
#  RGB{Float32}(0.894118,0.937255,0.913725)     RGB{Float32}(0.67451,0.764706,0.717647)
#  RGB{Float32}(0.862745,0.913725,0.894118)     RGB{Float32}(0.721569,0.784314,0.729412)
#  ⋮                                         ⋱
#  RGB{Float32}(0.501961,0.572549,0.603922)     RGB{Float32}(0.631373,0.698039,0.717647)
#  RGB{Float32}(0.384314,0.454902,0.494118)     RGB{Float32}(0.517647,0.584314,0.611765)
#  RGB{Float32}(0.313726,0.4,0.447059)          RGB{Float32}(0.478431,0.545098,0.584314)
#  RGB{Float32}(0.270588,0.372549,0.407843)  …  RGB{Float32}(0.490196,0.560784,0.603922)
#  RGB{Float32}(0.223529,0.333333,0.380392)     RGB{Float32}(0.6,0.694118,0.729412)
#  RGB{Float32}(0.2,0.313726,0.364706)          RGB{Float32}(0.635294,0.721569,0.752941)
#  RGB{Float32}(0.176471,0.290196,0.337255)     RGB{Float32}(0.721569,0.784314,0.815686)
#  RGB{Float32}(0.188235,0.298039,0.341176)     RGB{Float32}(0.623529,0.694118,0.733333)
#  RGB{Float32}(0.180392,0.305882,0.34902)   …  RGB{Float32}(0.686275,0.752941,0.784314)
#  RGB{Float32}(0.145098,0.266667,0.317647)     RGB{Float32}(0.717647,0.780392,0.811765)
#  RGB{Float32}(0.160784,0.282353,0.32549)      RGB{Float32}(0.666667,0.729412,0.760784)
#  RGB{Float32}(0.176471,0.301961,0.341176)     RGB{Float32}(0.47451,0.560784,0.596078)

# %% [markdown]
# ## The VAE

# %% [markdown]
# **Encoder and decoder**
# are defined as as multi-layer perceptrons (encoder output is twice the size of decoder
# input because of the need for mean and variance for each of the VAE codes):

# %%
actf = relu
encoder = Chain(
    Dense(64*64*3, 512, actf=actf),
    Dense(512, 64, actf=actf),
    Dense(64, 16, actf=identity))

decoder = Chain(
    Dense(8, 64, actf=actf),
    Dense(64, 512, actf=actf),
    Dense(512, 64*64*3, actf=identity))

vae = VAE(encoder, decoder)
# Out:
# VAE(Chain[Chain((Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(512,12288)), P(Knet.KnetArrays.KnetVector{Float32}(512)), Knet.Ops20.relu), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(64,512)), P(Knet.KnetArrays.KnetVector{Float32}(64)), Knet.Ops20.relu), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(16,64)), P(Knet.KnetArrays.KnetVector{Float32}(16)), identity))), Chain((Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(64,8)), P(Knet.KnetArrays.KnetVector{Float32}(64)), Knet.Ops20.relu), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(512,64)), P(Knet.KnetArrays.KnetVector{Float32}(512)), Knet.Ops20.relu), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(12288,512)), P(Knet.KnetArrays.KnetVector{Float32}(12288)), identity)))])

# %%
print_network(vae)
# Out:
# Neural network summary:
# VAE with 2 layers,                                            12663440 params
# Details:
#
#     Chain with 3 layers,                                       6325840 params
#
#         Dense layer 12288 → 512 with relu,                     6291968 params
#         Dense layer 512 → 64 with relu,                          32832 params
#         Dense layer 64 → 16 with identity,                        1040 params
#
#     Chain with 3 layers,                                       6337600 params
#
#         Dense layer 8 → 64 with relu,                              576 params
#         Dense layer 64 → 512 with relu,                          33280 params
#         Dense layer 512 → 12288 with identity,                 6303744 params
#
#
# Total number of layers: 6
# Total number of parameters: 12663440
# 6

# %% [markdown]
# ### Training:
#
# Alle images are stored as one minibatch, with the input also used as teaching input (i.e. x == y).
# The training is done with a (likely too) high number of epochs and a small learning rate, in order to get best possible
# reconstruction (to the cost of massive overfitting).

# %%
mbs = minibatch(trn, trn, 5)
# Out:
# 1-element Knet.Train20.Data{Tuple{KnetArray{Float32}, KnetArray{Float32}}}

# %%
vae(trn, trn)
# Out:
# 11038.377f0

# %%
tb_train!(vae, Adam, mbs, mbs, epochs=10000, lr=0.0001)
y = vae(trn)
[array2image(reshape(y[:,i], 64,64,3)) for i in 1:5]
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:26m
# Training 10000 epochs with 1 minibatches/epoch
#     (and 1 validation mbs).
# Evaluation is performed every 1 minibatches (with 1 mbs).
# Watch the progress with TensorBoard at: /home/andreas/.julia/dev/NNHelferlein/examples/logs/run/2021-12-19T16-33-47
# Training finished with:
# Training loss:       70.89945220947266
# Validation loss:     54.117244720458984
# 5-element Vector{Base.ReinterpretArray{RGB{Float32}, 2, Float32, Array{Float32, 3}, true}}:
#  [RGB{Float32}(0.44941267f0,0.6665662f0,0.68625635f0) RGB{Float32}(0.44721308f0,0.66459244f0,0.68806106f0) … RGB{Float32}(0.76579964f0,0.8395451f0,0.80887914f0) RGB{Float32}(0.6291854f0,0.7600773f0,0.7545823f0); RGB{Float32}(0.3197679f0,0.58782f0,0.62936807f0) RGB{Float32}(0.30879384f0,0.5889317f0,0.6292277f0) … RGB{Float32}(0.5507449f0,0.72239906f0,0.71672416f0) RGB{Float32}(0.4706859f0,0.67550236f0,0.6957852f0); … ; RGB{Float32}(0.15187526f0,0.283f0,0.32748216f0) RGB{Float32}(0.16624425f0,0.28667596f0,0.33145872f0) … RGB{Float32}(0.5796435f0,0.65604514f0,0.68824637f0) RGB{Float32}(0.67962754f0,0.75098467f0,0.7792588f0); RGB{Float32}(0.16815679f0,0.3050976f0,0.34295276f0) RGB{Float32}(0.15712968f0,0.2800267f0,0.3237761f0) … RGB{Float32}(0.44088447f0,0.54233056f0,0.5774618f0) RGB{Float32}(0.47659826f0,0.56827277f0,0.60253954f0)]
#  [RGB{Float32}(0.44258043f0,0.35745257f0,0.261386f0) RGB{Float32}(0.44602445f0,0.35497835f0,0.24860127f0) … RGB{Float32}(0.48795176f0,0.48664182f0,0.47040907f0) RGB{Float32}(0.48902175f0,0.47594637f0,0.46548596f0); RGB{Float32}(0.4750655f0,0.39726537f0,0.28239152f0) RGB{Float32}(0.47698665f0,0.37927735f0,0.2833384f0) … RGB{Float32}(0.4896415f0,0.47913605f0,0.46597138f0) RGB{Float32}(0.4775691f0,0.47321478f0,0.45574623f0); … ; RGB{Float32}(0.57723576f0,0.42576733f0,0.52346295f0) RGB{Float32}(0.8893771f0,0.81786966f0,0.9072346f0) … RGB{Float32}(0.9891279f0,0.88559574f0,1.0119101f0) RGB{Float32}(0.9856306f0,0.8892222f0,1.0087284f0); RGB{Float32}(0.5494189f0,0.38803032f0,0.49124798f0) RGB{Float32}(0.94915307f0,0.8683412f0,0.96513003f0) … RGB{Float32}(0.9948537f0,0.8761674f0,0.9964017f0) RGB{Float32}(0.9888261f0,0.88668704f0,1.0096083f0)]
#  [RGB{Float32}(0.3403521f0,0.33156574f0,0.35431954f0) RGB{Float32}(0.36947408f0,0.32417637f0,0.32104993f0) … RGB{Float32}(0.45616096f0,0.25093782f0,0.22196287f0) RGB{Float32}(0.4413862f0,0.3293739f0,0.30352056f0); RGB{Float32}(0.355525f0,0.33612406f0,0.35961598f0) RGB{Float32}(0.36878863f0,0.33021036f0,0.3061532f0) … RGB{Float32}(0.46890467f0,0.26024735f0,0.23938136f0) RGB{Float32}(0.43861616f0,0.3380933f0,0.3078788f0); … ; RGB{Float32}(0.40271425f0,0.30407164f0,0.42225936f0) RGB{Float32}(0.38425767f0,0.31641173f0,0.41467237f0) … RGB{Float32}(0.4226578f0,0.36441016f0,0.3549877f0) RGB{Float32}(0.42321092f0,0.3624188f0,0.3567179f0); RGB{Float32}(0.39973935f0,0.3029526f0,0.4076942f0) RGB{Float32}(0.3823266f0,0.31393623f0,0.4152965f0) … RGB{Float32}(0.42606708f0,0.3745908f0,0.36490887f0) RGB{Float32}(0.4271328f0,0.36950135f0,0.3506764f0)]
#  [RGB{Float32}(0.9343307f0,0.9319636f0,0.9310427f0) RGB{Float32}(0.937877f0,0.9368617f0,0.93206143f0) … RGB{Float32}(0.9688471f0,0.96856284f0,0.9654633f0) RGB{Float32}(0.9656166f0,0.96775806f0,0.9662977f0); RGB{Float32}(0.93662757f0,0.9333854f0,0.9289278f0) RGB{Float32}(0.9392832f0,0.9358481f0,0.9362249f0) … RGB{Float32}(0.9695811f0,0.9706072f0,0.9646435f0) RGB{Float32}(0.9700653f0,0.9703582f0,0.9657317f0); … ; RGB{Float32}(0.8889759f0,0.8930914f0,0.8910708f0) RGB{Float32}(0.89172417f0,0.8944613f0,0.89080876f0) … RGB{Float32}(0.9077605f0,0.9080579f0,0.9067365f0) RGB{Float32}(0.9011691f0,0.9073244f0,0.9013698f0); RGB{Float32}(0.8900689f0,0.890432f0,0.89359593f0) RGB{Float32}(0.88655496f0,0.8881864f0,0.88867974f0) … RGB{Float32}(0.9034571f0,0.90450495f0,0.90509135f0) RGB{Float32}(0.9052375f0,0.9027676f0,0.9044353f0)]
#  [RGB{Float32}(0.2820304f0,0.5306897f0,0.95925844f0) RGB{Float32}(0.28113404f0,0.52711535f0,0.9515231f0) … RGB{Float32}(0.28540242f0,0.51730716f0,0.93918717f0) RGB{Float32}(0.27278748f0,0.5277786f0,0.9276185f0); RGB{Float32}(0.29198885f0,0.5295538f0,0.95478165f0) RGB{Float32}(0.28975746f0,0.5291198f0,0.9507372f0) … RGB{Float32}(0.28126156f0,0.52304494f0,0.93714124f0) RGB{Float32}(0.27357012f0,0.5228617f0,0.92712945f0); … ; RGB{Float32}(0.7390965f0,0.63373417f0,0.5403294f0) RGB{Float32}(0.74216306f0,0.66259634f0,0.5756535f0) … RGB{Float32}(0.78769356f0,0.755575f0,0.6977906f0) RGB{Float32}(0.8010686f0,0.7688653f0,0.75933766f0); RGB{Float32}(0.73490727f0,0.65247715f0,0.55975735f0) RGB{Float32}(0.7950995f0,0.6927795f0,0.6521714f0) … RGB{Float32}(0.7435587f0,0.6867199f0,0.6109739f0) RGB{Float32}(0.7885311f0,0.724257f0,0.6798143f0)]

# %% [markdown]
# ### Experiments:

# %%
code_car = encoder(trn[:,1])[1:8]
code_tree = encoder(trn[:,5])[1:8]
code_spock = encoder(trn[:,3])[1:8]
# Out:
# 8-element Knet.KnetArrays.KnetVector{Float32}:
#   1.5272909
#   0.1149718
#  -0.69533604
#   0.027628675
#  -0.50833714
#  -0.105582885
#   0.10758206
#   0.4042787

# %%
[array2image(reshape(decoder(code_car), 64,64,3)),
 array2image(reshape(decoder(code_tree), 64,64,3))]
# Out:
# 2-element Vector{Base.ReinterpretArray{RGB{Float32}, 2, Float32, Array{Float32, 3}, true}}:
#  [RGB{Float32}(0.42462102f0,0.6294512f0,0.6596223f0) RGB{Float32}(0.42511275f0,0.6280983f0,0.6567778f0) … RGB{Float32}(0.72543347f0,0.7947488f0,0.7679421f0) RGB{Float32}(0.594148f0,0.71685284f0,0.72311205f0); RGB{Float32}(0.3086858f0,0.56179255f0,0.6037423f0) RGB{Float32}(0.2935763f0,0.5610518f0,0.6012376f0) … RGB{Float32}(0.51561403f0,0.686601f0,0.6879939f0) RGB{Float32}(0.4426396f0,0.64270645f0,0.6649174f0); … ; RGB{Float32}(0.15917426f0,0.28166428f0,0.3193244f0) RGB{Float32}(0.17289539f0,0.28121182f0,0.32594836f0) … RGB{Float32}(0.55911225f0,0.6286555f0,0.654047f0) RGB{Float32}(0.65058476f0,0.7153223f0,0.7397472f0); RGB{Float32}(0.17321911f0,0.29701823f0,0.33793297f0) RGB{Float32}(0.16616173f0,0.27547762f0,0.31988564f0) … RGB{Float32}(0.4287749f0,0.5254058f0,0.5537775f0) RGB{Float32}(0.4641664f0,0.5514284f0,0.5829223f0)]
#  [RGB{Float32}(0.271693f0,0.5337639f0,1.0074005f0) RGB{Float32}(0.27477595f0,0.5379481f0,1.0038165f0) … RGB{Float32}(0.26248533f0,0.5252245f0,0.9784265f0) RGB{Float32}(0.2573277f0,0.52645445f0,0.97382563f0); RGB{Float32}(0.28646326f0,0.5417346f0,1.0119656f0) RGB{Float32}(0.29082128f0,0.5396757f0,1.0113539f0) … RGB{Float32}(0.2644174f0,0.5302238f0,0.9751116f0) RGB{Float32}(0.26041973f0,0.5283755f0,0.976704f0); … ; RGB{Float32}(0.78224546f0,0.6601026f0,0.55587053f0) RGB{Float32}(0.7695097f0,0.68517506f0,0.57939833f0) … RGB{Float32}(0.8008301f0,0.7766468f0,0.7026948f0) RGB{Float32}(0.8225529f0,0.77780426f0,0.7710848f0); RGB{Float32}(0.7701298f0,0.6791097f0,0.5819118f0) RGB{Float32}(0.8325496f0,0.7217595f0,0.66691697f0) … RGB{Float32}(0.7560258f0,0.7071624f0,0.61486137f0) RGB{Float32}(0.80784285f0,0.7486493f0,0.6828112f0)]

# %% [markdown]
# This is the ability of a variational autoencoder:
# even the highly overfitted autoencoder has a perfectly regularised codebook and
# interpolates perfectly between trained patterns!

# %%
array2image(reshape(decoder(code_car*0.8 + code_tree*0.2), 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.387603,0.591114,0.640476)  …  RGB{Float32}(0.546047,0.655222,0.694623)
#  RGB{Float32}(0.290951,0.525544,0.592999)     RGB{Float32}(0.403122,0.60679,0.64421)
#  RGB{Float32}(0.281045,0.529008,0.600216)     RGB{Float32}(0.304771,0.55693,0.621671)
#  RGB{Float32}(0.315081,0.559135,0.612028)     RGB{Float32}(0.277386,0.551011,0.612116)
#  RGB{Float32}(0.375975,0.595072,0.649732)     RGB{Float32}(0.260848,0.542137,0.605632)
#  RGB{Float32}(0.446489,0.63669,0.682615)   …  RGB{Float32}(0.301058,0.551022,0.61313)
#  RGB{Float32}(0.530057,0.70242,0.7267)        RGB{Float32}(0.369307,0.580175,0.636206)
#  RGB{Float32}(0.614861,0.747803,0.764892)     RGB{Float32}(0.358386,0.562893,0.624929)
#  RGB{Float32}(0.672514,0.772844,0.788498)     RGB{Float32}(0.517801,0.664007,0.678589)
#  RGB{Float32}(0.725039,0.807531,0.821939)     RGB{Float32}(0.676897,0.739892,0.7202)
#  RGB{Float32}(0.793508,0.837493,0.853357)  …  RGB{Float32}(0.61255,0.70199,0.692597)
#  RGB{Float32}(0.794952,0.84251,0.844642)      RGB{Float32}(0.605338,0.696504,0.687845)
#  RGB{Float32}(0.770674,0.828044,0.836453)     RGB{Float32}(0.644334,0.711551,0.687581)
#  ⋮                                         ⋱
#  RGB{Float32}(0.464856,0.544335,0.58837)      RGB{Float32}(0.581837,0.647293,0.678507)
#  RGB{Float32}(0.368743,0.430334,0.490048)     RGB{Float32}(0.47995,0.548401,0.583507)
#  RGB{Float32}(0.306633,0.395168,0.448507)     RGB{Float32}(0.44556,0.525908,0.568227)
#  RGB{Float32}(0.275993,0.376105,0.407013)  …  RGB{Float32}(0.459481,0.527938,0.582937)
#  RGB{Float32}(0.228373,0.340185,0.387733)     RGB{Float32}(0.549541,0.648376,0.692267)
#  RGB{Float32}(0.207937,0.320492,0.378688)     RGB{Float32}(0.588489,0.674124,0.714333)
#  RGB{Float32}(0.18923,0.298615,0.360565)      RGB{Float32}(0.664721,0.723035,0.76291)
#  RGB{Float32}(0.20895,0.307095,0.355937)      RGB{Float32}(0.58037,0.647321,0.708576)
#  RGB{Float32}(0.195822,0.305005,0.336883)  …  RGB{Float32}(0.62207,0.678601,0.702381)
#  RGB{Float32}(0.17158,0.27392,0.30548)        RGB{Float32}(0.64988,0.711911,0.737277)
#  RGB{Float32}(0.177395,0.292857,0.31583)      RGB{Float32}(0.623881,0.677165,0.697764)
#  RGB{Float32}(0.199488,0.30273,0.327905)      RGB{Float32}(0.458638,0.526747,0.556645)

# %%
array2image(reshape(decoder(code_car*0.6 + code_tree*0.4), 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.297987,0.545217,0.723981)  …  RGB{Float32}(0.413886,0.575724,0.746)
#  RGB{Float32}(0.238852,0.493047,0.696482)     RGB{Float32}(0.306504,0.54229,0.724637)
#  RGB{Float32}(0.226773,0.504674,0.698354)     RGB{Float32}(0.243286,0.512381,0.721457)
#  RGB{Float32}(0.252148,0.51393,0.70651)       RGB{Float32}(0.223329,0.513088,0.693391)
#  RGB{Float32}(0.300721,0.5336,0.72832)        RGB{Float32}(0.217246,0.505043,0.706025)
#  RGB{Float32}(0.349242,0.569662,0.755691)  …  RGB{Float32}(0.240098,0.513959,0.71161)
#  RGB{Float32}(0.403986,0.619672,0.787932)     RGB{Float32}(0.300254,0.52822,0.725124)
#  RGB{Float32}(0.471264,0.645757,0.814076)     RGB{Float32}(0.299715,0.524684,0.717774)
#  RGB{Float32}(0.522793,0.67447,0.836465)      RGB{Float32}(0.41681,0.593279,0.753667)
#  RGB{Float32}(0.554046,0.702195,0.859905)     RGB{Float32}(0.53243,0.650372,0.790183)
#  RGB{Float32}(0.61303,0.727985,0.892486)   …  RGB{Float32}(0.47784,0.648336,0.774561)
#  RGB{Float32}(0.615959,0.736099,0.871123)     RGB{Float32}(0.480543,0.63259,0.766127)
#  RGB{Float32}(0.601942,0.726678,0.875576)     RGB{Float32}(0.509609,0.641911,0.760081)
#  ⋮                                         ⋱
#  RGB{Float32}(0.486986,0.602878,0.699756)     RGB{Float32}(0.558364,0.673078,0.769446)
#  RGB{Float32}(0.424953,0.518861,0.625488)     RGB{Float32}(0.48944,0.600243,0.695426)
#  RGB{Float32}(0.377588,0.505454,0.601649)     RGB{Float32}(0.464833,0.58392,0.69123)
#  RGB{Float32}(0.350742,0.48939,0.574886)   …  RGB{Float32}(0.484337,0.595021,0.707898)
#  RGB{Float32}(0.318805,0.461824,0.547877)     RGB{Float32}(0.545819,0.674325,0.786672)
#  RGB{Float32}(0.308625,0.443188,0.552423)     RGB{Float32}(0.57024,0.704573,0.784125)
#  RGB{Float32}(0.298378,0.420843,0.528165)     RGB{Float32}(0.617369,0.718426,0.812524)
#  RGB{Float32}(0.30148,0.434028,0.522552)      RGB{Float32}(0.546265,0.653322,0.767132)
#  RGB{Float32}(0.320091,0.385611,0.400948)  …  RGB{Float32}(0.542988,0.576952,0.585385)
#  RGB{Float32}(0.31745,0.36653,0.341712)       RGB{Float32}(0.604551,0.643556,0.633476)
#  RGB{Float32}(0.31747,0.36981,0.345581)       RGB{Float32}(0.638681,0.669331,0.680851)
#  RGB{Float32}(0.331389,0.385015,0.367968)     RGB{Float32}(0.522748,0.548502,0.54249)

# %%
array2image(reshape(decoder(code_car*0.5 + code_tree*0.5), 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.277182,0.530076,0.795483)  …  RGB{Float32}(0.34955,0.543378,0.798722)
#  RGB{Float32}(0.242771,0.492726,0.776469)     RGB{Float32}(0.281921,0.522442,0.786136)
#  RGB{Float32}(0.235377,0.504149,0.777721)     RGB{Float32}(0.242821,0.502519,0.78579)
#  RGB{Float32}(0.253028,0.506464,0.7846)       RGB{Float32}(0.228859,0.506506,0.762652)
#  RGB{Float32}(0.286339,0.519341,0.795305)     RGB{Float32}(0.232145,0.503315,0.777822)
#  RGB{Float32}(0.321166,0.549911,0.819522)  …  RGB{Float32}(0.245234,0.507636,0.780084)
#  RGB{Float32}(0.358154,0.579959,0.8417)       RGB{Float32}(0.290892,0.515683,0.791396)
#  RGB{Float32}(0.402484,0.601278,0.859134)     RGB{Float32}(0.294458,0.520575,0.788935)
#  RGB{Float32}(0.44202,0.624876,0.875194)      RGB{Float32}(0.370835,0.568463,0.815882)
#  RGB{Float32}(0.467247,0.64852,0.893145)      RGB{Float32}(0.447278,0.60966,0.844221)
#  RGB{Float32}(0.510354,0.663356,0.917464)  …  RGB{Float32}(0.412996,0.615434,0.829987)
#  RGB{Float32}(0.514067,0.668675,0.898658)     RGB{Float32}(0.41639,0.600084,0.827597)
#  RGB{Float32}(0.508037,0.666284,0.901695)     RGB{Float32}(0.440199,0.606828,0.821633)
#  ⋮                                         ⋱
#  RGB{Float32}(0.515717,0.654379,0.786813)     RGB{Float32}(0.554344,0.693197,0.8368)
#  RGB{Float32}(0.47909,0.601463,0.737602)      RGB{Float32}(0.513261,0.64746,0.785943)
#  RGB{Float32}(0.450833,0.597467,0.717597)     RGB{Float32}(0.493567,0.638492,0.784646)
#  RGB{Float32}(0.431644,0.585388,0.706622)  …  RGB{Float32}(0.516133,0.64658,0.794038)
#  RGB{Float32}(0.413003,0.567746,0.684352)     RGB{Float32}(0.554952,0.702819,0.850406)
#  RGB{Float32}(0.407377,0.556618,0.691072)     RGB{Float32}(0.573207,0.725357,0.837707)
#  RGB{Float32}(0.404147,0.544701,0.669071)     RGB{Float32}(0.602504,0.729574,0.856056)
#  RGB{Float32}(0.404205,0.551688,0.665543)     RGB{Float32}(0.552113,0.681526,0.820541)
#  RGB{Float32}(0.441845,0.47768,0.477158)   …  RGB{Float32}(0.525946,0.528034,0.533278)
#  RGB{Float32}(0.455376,0.458908,0.400712)     RGB{Float32}(0.593561,0.615816,0.591678)
#  RGB{Float32}(0.447218,0.450975,0.398301)     RGB{Float32}(0.67892,0.682912,0.688274)
#  RGB{Float32}(0.455055,0.467093,0.425862)     RGB{Float32}(0.594872,0.590775,0.566982)

# %%
array2image(reshape(decoder(code_car*0.2 + code_tree*0.8), 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.263469,0.509617,0.939129)  …  RGB{Float32}(0.25374,0.504092,0.911273)
#  RGB{Float32}(0.278792,0.512582,0.943202)     RGB{Float32}(0.258505,0.498444,0.915745)
#  RGB{Float32}(0.285398,0.51076,0.947397)      RGB{Float32}(0.265521,0.506385,0.919052)
#  RGB{Float32}(0.287741,0.518535,0.9456)       RGB{Float32}(0.270122,0.512271,0.920748)
#  RGB{Float32}(0.289887,0.523332,0.944269)     RGB{Float32}(0.28121,0.51398,0.926396)
#  RGB{Float32}(0.296464,0.52906,0.959613)   …  RGB{Float32}(0.282628,0.515947,0.929053)
#  RGB{Float32}(0.304121,0.522443,0.958746)     RGB{Float32}(0.290783,0.519895,0.93339)
#  RGB{Float32}(0.306389,0.5324,0.958698)       RGB{Float32}(0.30066,0.528413,0.9349)
#  RGB{Float32}(0.313207,0.54449,0.957066)      RGB{Float32}(0.299554,0.534666,0.9418)
#  RGB{Float32}(0.319508,0.548002,0.968914)     RGB{Float32}(0.308525,0.538567,0.952405)
#  RGB{Float32}(0.33158,0.544997,0.966675)   …  RGB{Float32}(0.309601,0.548471,0.94599)
#  RGB{Float32}(0.334785,0.554573,0.962141)     RGB{Float32}(0.318236,0.547415,0.950547)
#  RGB{Float32}(0.344431,0.556069,0.964586)     RGB{Float32}(0.328446,0.546224,0.945473)
#  ⋮                                         ⋱
#  RGB{Float32}(0.57896,0.758024,0.965591)      RGB{Float32}(0.559188,0.737375,0.963517)
#  RGB{Float32}(0.588174,0.769479,0.967263)     RGB{Float32}(0.567616,0.753516,0.963987)
#  RGB{Float32}(0.602604,0.778768,0.96407)      RGB{Float32}(0.571665,0.754372,0.968745)
#  RGB{Float32}(0.605089,0.785169,0.963774)  …  RGB{Float32}(0.577232,0.753255,0.959922)
#  RGB{Float32}(0.611105,0.78324,0.961837)      RGB{Float32}(0.582716,0.762317,0.965804)
#  RGB{Float32}(0.609867,0.784236,0.96357)      RGB{Float32}(0.590279,0.764946,0.951539)
#  RGB{Float32}(0.621543,0.791554,0.959278)     RGB{Float32}(0.597912,0.767342,0.960588)
#  RGB{Float32}(0.62144,0.794682,0.955692)      RGB{Float32}(0.600225,0.754439,0.942546)
#  RGB{Float32}(0.705045,0.666589,0.641793)  …  RGB{Float32}(0.529999,0.449876,0.467469)
#  RGB{Float32}(0.752291,0.659122,0.543263)     RGB{Float32}(0.610885,0.583789,0.534516)
#  RGB{Float32}(0.728557,0.624707,0.525094)     RGB{Float32}(0.776409,0.732599,0.724837)
#  RGB{Float32}(0.723494,0.637567,0.549892)     RGB{Float32}(0.763658,0.7021,0.645186)

# %%
array2image(reshape(decoder(code_spock), 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.363591,0.347599,0.368461)  …  RGB{Float32}(0.451607,0.340314,0.318608)
#  RGB{Float32}(0.369464,0.353608,0.370665)     RGB{Float32}(0.448548,0.345756,0.319075)
#  RGB{Float32}(0.372738,0.351256,0.373603)     RGB{Float32}(0.440144,0.350108,0.322392)
#  RGB{Float32}(0.374036,0.359422,0.374739)     RGB{Float32}(0.433206,0.35785,0.333061)
#  RGB{Float32}(0.387662,0.3744,0.385377)       RGB{Float32}(0.431194,0.35135,0.33724)
#  RGB{Float32}(0.389375,0.378487,0.38989)   …  RGB{Float32}(0.43561,0.355856,0.343448)
#  RGB{Float32}(0.397397,0.380931,0.406097)     RGB{Float32}(0.434128,0.358208,0.339416)
#  RGB{Float32}(0.407614,0.388404,0.410434)     RGB{Float32}(0.434227,0.355283,0.339715)
#  RGB{Float32}(0.425959,0.392578,0.419592)     RGB{Float32}(0.43333,0.36051,0.347188)
#  RGB{Float32}(0.434498,0.391092,0.423606)     RGB{Float32}(0.432756,0.355868,0.340021)
#  RGB{Float32}(0.438785,0.405865,0.42522)   …  RGB{Float32}(0.440893,0.359611,0.337728)
#  RGB{Float32}(0.438343,0.412423,0.41727)      RGB{Float32}(0.439765,0.361694,0.337783)
#  RGB{Float32}(0.441517,0.420218,0.4317)       RGB{Float32}(0.442673,0.360274,0.338865)
#  ⋮                                         ⋱
#  RGB{Float32}(0.388515,0.306768,0.4113)       RGB{Float32}(0.433586,0.366813,0.34708)
#  RGB{Float32}(0.405837,0.316997,0.431957)     RGB{Float32}(0.432121,0.367311,0.345036)
#  RGB{Float32}(0.403866,0.316706,0.428914)     RGB{Float32}(0.436701,0.367211,0.345583)
#  RGB{Float32}(0.383101,0.296827,0.403049)  …  RGB{Float32}(0.4338,0.359096,0.344801)
#  RGB{Float32}(0.361893,0.283885,0.384721)     RGB{Float32}(0.431745,0.365002,0.350177)
#  RGB{Float32}(0.352126,0.272542,0.373705)     RGB{Float32}(0.440494,0.370021,0.364037)
#  RGB{Float32}(0.364449,0.288241,0.388483)     RGB{Float32}(0.442422,0.377014,0.363612)
#  RGB{Float32}(0.391918,0.32277,0.418154)      RGB{Float32}(0.442647,0.38086,0.367011)
#  RGB{Float32}(0.3944,0.310459,0.421451)    …  RGB{Float32}(0.443473,0.378145,0.36251)
#  RGB{Float32}(0.399986,0.314975,0.423142)     RGB{Float32}(0.443215,0.381641,0.36373)
#  RGB{Float32}(0.405244,0.325496,0.426658)     RGB{Float32}(0.434729,0.378189,0.373626)
#  RGB{Float32}(0.400593,0.313839,0.41993)      RGB{Float32}(0.438193,0.378281,0.378187)

# %% [markdown]
# fascinating!
