# %% [markdown]
# # Vanilla Autoencoder
#
# The notebook shows how simple autoencoders built from fully connected layers can be
# designed with Knet and Helferlein.
# The 64x64 example images are in the NNHelderlein data-directory.

# %%
using Knet
using NNHelferlein
using Images

# %% [markdown]
# ### Data
# Load images from directory, flatten the 64x64x3 tensors to a 1-D-vecor and
# build a matrix with 12288 rows (= RGB-values of all pixels) and
# 4 columns (= number of pictures).
#
# Training data must be flattened because each image is represented by a 1D-vector
# in the perceptron.
# Final training tensor is (num-pixels x 3) x (num images):

# %%
d = joinpath(NNHelferlein.DATA_DIR, "Images64")
imgs = [load(joinpath(d, i)) for i in readdir(d) if occursin("png", i)]
# Out:
# 5-element Vector{Matrix{RGB{N0f8}}}:
#  [RGB{N0f8}(0.435,0.647,0.675) RGB{N0f8}(0.435,0.643,0.675) … RGB{N0f8}(0.741,0.812,0.784) RGB{N0f8}(0.612,0.737,0.737); RGB{N0f8}(0.314,0.573,0.62) RGB{N0f8}(0.302,0.573,0.616) … RGB{N0f8}(0.533,0.698,0.702) RGB{N0f8}(0.455,0.655,0.678); … ; RGB{N0f8}(0.161,0.282,0.325) RGB{N0f8}(0.176,0.286,0.333) … RGB{N0f8}(0.573,0.643,0.671) RGB{N0f8}(0.667,0.729,0.761); RGB{N0f8}(0.176,0.302,0.341) RGB{N0f8}(0.169,0.282,0.325) … RGB{N0f8}(0.439,0.537,0.565) RGB{N0f8}(0.475,0.561,0.596)]
#  [RGB{N0f8}(0.439,0.361,0.259) RGB{N0f8}(0.439,0.349,0.247) … RGB{N0f8}(0.49,0.478,0.459) RGB{N0f8}(0.486,0.471,0.455); RGB{N0f8}(0.471,0.392,0.282) RGB{N0f8}(0.471,0.376,0.278) … RGB{N0f8}(0.486,0.471,0.451) RGB{N0f8}(0.478,0.467,0.447); … ; RGB{N0f8}(0.565,0.42,0.518) RGB{N0f8}(0.867,0.796,0.886) … RGB{N0f8}(0.969,0.867,0.984) RGB{N0f8}(0.965,0.867,0.984); RGB{N0f8}(0.541,0.384,0.486) RGB{N0f8}(0.918,0.847,0.945) … RGB{N0f8}(0.965,0.851,0.969) RGB{N0f8}(0.965,0.867,0.984)]
#  [RGB{N0f8}(0.369,0.349,0.373) RGB{N0f8}(0.376,0.333,0.322) … RGB{N0f8}(0.482,0.263,0.224) RGB{N0f8}(0.459,0.337,0.314); RGB{N0f8}(0.373,0.353,0.376) RGB{N0f8}(0.376,0.337,0.325) … RGB{N0f8}(0.478,0.278,0.235) RGB{N0f8}(0.459,0.345,0.318); … ; RGB{N0f8}(0.416,0.325,0.439) RGB{N0f8}(0.408,0.329,0.439) … RGB{N0f8}(0.439,0.376,0.373) RGB{N0f8}(0.439,0.376,0.369); RGB{N0f8}(0.408,0.318,0.431) RGB{N0f8}(0.404,0.325,0.435) … RGB{N0f8}(0.439,0.376,0.376) RGB{N0f8}(0.439,0.376,0.373)]
#  [RGB{N0f8}(0.949,0.949,0.949) RGB{N0f8}(0.953,0.953,0.953) … RGB{N0f8}(0.984,0.984,0.984) RGB{N0f8}(0.984,0.984,0.984); RGB{N0f8}(0.949,0.949,0.949) RGB{N0f8}(0.953,0.953,0.953) … RGB{N0f8}(0.984,0.984,0.984) RGB{N0f8}(0.984,0.984,0.984); … ; RGB{N0f8}(0.906,0.906,0.906) RGB{N0f8}(0.91,0.91,0.91) … RGB{N0f8}(0.925,0.925,0.925) RGB{N0f8}(0.922,0.922,0.922); RGB{N0f8}(0.906,0.906,0.906) RGB{N0f8}(0.906,0.906,0.906) … RGB{N0f8}(0.922,0.922,0.922) RGB{N0f8}(0.922,0.922,0.922)]
#  [RGB{N0f8}(0.267,0.525,0.973) RGB{N0f8}(0.271,0.529,0.973) … RGB{N0f8}(0.259,0.518,0.949) RGB{N0f8}(0.255,0.514,0.945); RGB{N0f8}(0.282,0.525,0.976) RGB{N0f8}(0.286,0.525,0.976) … RGB{N0f8}(0.263,0.522,0.953) RGB{N0f8}(0.259,0.518,0.953); … ; RGB{N0f8}(0.761,0.643,0.545) RGB{N0f8}(0.757,0.671,0.573) … RGB{N0f8}(0.784,0.757,0.69) RGB{N0f8}(0.808,0.761,0.761); RGB{N0f8}(0.753,0.663,0.569) RGB{N0f8}(0.816,0.71,0.655) … RGB{N0f8}(0.745,0.694,0.608) RGB{N0f8}(0.792,0.733,0.675)]

# %%
trn = hcat(vec.(image2array.(imgs))...)
trn = convert2KnetArray(trn)
size(trn)
# Out:
# (12288, 5)

# %% [markdown]
# Here is how to get the images back from the tensors:

# %%
array2image(reshape(trn[:,1], 64,64,3))
# Out:
# 64×64 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.435294,0.647059,0.67451)   …  RGB{Float32}(0.611765,0.737255,0.737255)
#  RGB{Float32}(0.313726,0.572549,0.619608)     RGB{Float32}(0.454902,0.654902,0.678431)
#  RGB{Float32}(0.305882,0.580392,0.623529)     RGB{Float32}(0.341176,0.607843,0.654902)
#  RGB{Float32}(0.345098,0.603922,0.639216)     RGB{Float32}(0.305882,0.596078,0.639216)
#  RGB{Float32}(0.411765,0.65098,0.686275)      RGB{Float32}(0.290196,0.584314,0.631373)
#  RGB{Float32}(0.498039,0.698039,0.717647)  …  RGB{Float32}(0.32549,0.6,0.643137)
#  RGB{Float32}(0.6,0.772549,0.772549)          RGB{Float32}(0.411765,0.635294,0.67451)
#  RGB{Float32}(0.701961,0.823529,0.815686)     RGB{Float32}(0.392157,0.619608,0.654902)
#  RGB{Float32}(0.760784,0.854902,0.843137)     RGB{Float32}(0.580392,0.72549,0.713726)
#  RGB{Float32}(0.815686,0.898039,0.87451)      RGB{Float32}(0.764706,0.823529,0.760784)
#  RGB{Float32}(0.886275,0.933333,0.913725)  …  RGB{Float32}(0.686275,0.768627,0.729412)
#  RGB{Float32}(0.894118,0.937255,0.913725)     RGB{Float32}(0.67451,0.764706,0.717647)
#  RGB{Float32}(0.862745,0.913725,0.894118)     RGB{Float32}(0.721569,0.784314,0.729412)
#  ⋮                                         ⋱
#  RGB{Float32}(0.501961,0.572549,0.603922)     RGB{Float32}(0.631373,0.698039,0.717647)
#  RGB{Float32}(0.384314,0.454902,0.494118)     RGB{Float32}(0.517647,0.584314,0.611765)
#  RGB{Float32}(0.313726,0.4,0.447059)          RGB{Float32}(0.478431,0.545098,0.584314)
#  RGB{Float32}(0.270588,0.372549,0.407843)  …  RGB{Float32}(0.490196,0.560784,0.603922)
#  RGB{Float32}(0.223529,0.333333,0.380392)     RGB{Float32}(0.6,0.694118,0.729412)
#  RGB{Float32}(0.2,0.313726,0.364706)          RGB{Float32}(0.635294,0.721569,0.752941)
#  RGB{Float32}(0.176471,0.290196,0.337255)     RGB{Float32}(0.721569,0.784314,0.815686)
#  RGB{Float32}(0.188235,0.298039,0.341176)     RGB{Float32}(0.623529,0.694118,0.733333)
#  RGB{Float32}(0.180392,0.305882,0.34902)   …  RGB{Float32}(0.686275,0.752941,0.784314)
#  RGB{Float32}(0.145098,0.266667,0.317647)     RGB{Float32}(0.717647,0.780392,0.811765)
#  RGB{Float32}(0.160784,0.282353,0.32549)      RGB{Float32}(0.666667,0.729412,0.760784)
#  RGB{Float32}(0.176471,0.301961,0.341176)     RGB{Float32}(0.47451,0.560784,0.596078)

# %% [markdown]
# ## The Autoencoder:
#
# Defining AutoEncoder as a subtype of `DNN` makes the overloaded `summary()` and `print_network()` functions working:

# %%
struct AutoEncoder <: DNN
    layers
    AutoEncoder(e,d) = new([e,d])
end

function (ae::AutoEncoder)(x)
    
    # encode - decode:
    #
    x = ae.layers[1](x)
    x = ae.layers[2](x)
    return x
end

# square loss:
#
(ae::AutoEncoder)(x, y) = sum(abs2, ae(x) .- y)

# %% [markdown]
# #### Define encoder and decoder as MLPs and combine them to the AE:

# %%
actf = sigm
encoder = Chain(
    Dense(64*64*3, 512, actf=actf),
    Dense(512, 64, actf=actf),
    Dense(64, 8, actf=actf))

decoder = Chain(
    Dense(8, 64, actf=actf),
    Dense(64, 512, actf=actf),
    Dense(512, 64*64*3, actf=actf))
# Out:
# Chain((Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(64,8)), P(Knet.KnetArrays.KnetVector{Float32}(64)), Knet.Ops20.sigm), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(512,64)), P(Knet.KnetArrays.KnetVector{Float32}(512)), Knet.Ops20.sigm), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(12288,512)), P(Knet.KnetArrays.KnetVector{Float32}(12288)), Knet.Ops20.sigm)))

# %%
ae = AutoEncoder(encoder, decoder)
# Out:
# AutoEncoder(Chain[Chain((Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(512,12288)), P(Knet.KnetArrays.KnetVector{Float32}(512)), Knet.Ops20.sigm), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(64,512)), P(Knet.KnetArrays.KnetVector{Float32}(64)), Knet.Ops20.sigm), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(8,64)), P(Knet.KnetArrays.KnetVector{Float32}(8)), Knet.Ops20.sigm))), Chain((Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(64,8)), P(Knet.KnetArrays.KnetVector{Float32}(64)), Knet.Ops20.sigm), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(512,64)), P(Knet.KnetArrays.KnetVector{Float32}(512)), Knet.Ops20.sigm), Dense(P(Knet.KnetArrays.KnetMatrix{Float32}(12288,512)), P(Knet.KnetArrays.KnetVector{Float32}(12288)), Knet.Ops20.sigm)))])

# %%
summary(ae)
# Out:
# "AutoEncoder with 2 layers,                                    12662920 params"

# %%
print_network(ae)
# Out:
# Neural network summary:
# AutoEncoder with 2 layers,                                    12662920 params
# Details:
#
#     Chain with 3 layers,                                       6325320 params
#
#         Dense layer 12288 → 512 with sigm,                     6291968 params
#         Dense layer 512 → 64 with sigm,                          32832 params
#         Dense layer 64 → 8 with sigm,                              520 params
#
#     Chain with 3 layers,                                       6337600 params
#
#         Dense layer 8 → 64 with sigm,                              576 params
#         Dense layer 64 → 512 with sigm,                          33280 params
#         Dense layer 512 → 12288 with sigm,                     6303744 params
#
#
# Total number of layers: 6
# Total number of parameters: 12662920
# 6

# %% [markdown]
# We test the AE with one argument (i.e. predict) and with two (i.e. calculate loss):

# %%
@show size(ae(trn))
@show loss = ae(trn, trn);
# Out:
# size(ae(trn)) = (12288, 5)
# loss = ae(trn, trn) = 5261.327f0

# %% [markdown]
# Create one minibatch with all 4 images (Knet default),
# train with NNHelferlein's `tb_train()` for about 1 min on a nvidia GPU
# and display the reconstructed images:

# %%
mbs = minibatch(trn, trn, 5)
# Out:
# 1-element Knet.Train20.Data{Tuple{KnetArray{Float32}, KnetArray{Float32}}}

# %%
ae = tb_train!(ae, Adam, mbs, epochs=5000, lr=0.0002)
y = ae(trn)
[array2image(reshape(y[:,i], 64,64,3)) for i in 1:size(y)[end]]
# Out:
# Training 5000 epochs with 1 minibatches/epoch
# Evaluation is performed every 1 minibatches (with 1 mbs).
# Watch the progress with TensorBoard at: /home/andreas/.julia/dev/NNHelferlein/examples/logs/run/2021-12-20T10-30-13
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:02
# Training finished with:
# Training loss:       11.200817108154297
# 5-element Vector{Base.ReinterpretArray{RGB{Float32}, 2, Float32, Array{Float32, 3}, true}}:
#  [RGB{Float32}(0.4353436f0,0.64706445f0,0.67438006f0) RGB{Float32}(0.43534568f0,0.64314586f0,0.6744168f0) … RGB{Float32}(0.74127144f0,0.8118771f0,0.7841769f0) RGB{Float32}(0.61185044f0,0.73728675f0,0.73710847f0); RGB{Float32}(0.3137805f0,0.5725653f0,0.61945784f0) RGB{Float32}(0.3020075f0,0.5725555f0,0.6155914f0) … RGB{Float32}(0.5334026f0,0.6980962f0,0.70181817f0) RGB{Float32}(0.45498273f0,0.65491986f0,0.6782866f0); … ; RGB{Float32}(0.16072679f0,0.28235555f0,0.32551777f0) RGB{Float32}(0.17639042f0,0.28625703f0,0.33333233f0) … RGB{Float32}(0.57248634f0,0.6431004f0,0.67063254f0) RGB{Float32}(0.6665856f0,0.72938323f0,0.76080114f0); RGB{Float32}(0.17643066f0,0.3019571f0,0.341193f0) RGB{Float32}(0.16841914f0,0.28233323f0,0.3254576f0) … RGB{Float32}(0.4391396f0,0.53724f0,0.5646939f0) RGB{Float32}(0.47441718f0,0.5607534f0,0.59610605f0)]
#  [RGB{Float32}(0.43923396f0,0.36078423f0,0.25877964f0) RGB{Float32}(0.43923625f0,0.3490187f0,0.24700862f0) … RGB{Float32}(0.4902325f0,0.47844872f0,0.4588294f0) RGB{Float32}(0.48631397f0,0.47059566f0,0.45490134f0); RGB{Float32}(0.4706103f0,0.39216134f0,0.28228393f0) RGB{Float32}(0.47062004f0,0.3764686f0,0.2783773f0) … RGB{Float32}(0.4863167f0,0.47060063f0,0.45096835f0) RGB{Float32}(0.4784649f0,0.46666726f0,0.44704694f0); … ; RGB{Float32}(0.5646996f0,0.41959202f0,0.5176721f0) RGB{Float32}(0.86662614f0,0.79604864f0,0.8863281f0) … RGB{Float32}(0.96748424f0,0.8666875f0,0.9790781f0) RGB{Float32}(0.9639772f0,0.86670023f0,0.98049957f0); RGB{Float32}(0.54116994f0,0.38429582f0,0.48627692f0) RGB{Float32}(0.91768426f0,0.84701896f0,0.9452445f0) … RGB{Float32}(0.96431476f0,0.85100126f0,0.9689604f0) RGB{Float32}(0.96431696f0,0.86668915f0,0.9797111f0)]
#  [RGB{Float32}(0.36862114f0,0.34900308f0,0.3726616f0) RGB{Float32}(0.3764691f0,0.33331233f0,0.32165077f0) … RGB{Float32}(0.4823014f0,0.2626733f0,0.22366683f0) RGB{Float32}(0.45878214f0,0.33722696f0,0.31386214f0); RGB{Float32}(0.37256393f0,0.35292372f0,0.37660882f0) RGB{Float32}(0.37645987f0,0.3372412f0,0.3255676f0) … RGB{Float32}(0.4784413f0,0.27838865f0,0.2354519f0) RGB{Float32}(0.45882747f0,0.3450819f0,0.3177809f0); … ; RGB{Float32}(0.41571847f0,0.32550126f0,0.43923748f0) RGB{Float32}(0.4079051f0,0.32945535f0,0.43924105f0) … RGB{Float32}(0.43936092f0,0.3765203f0,0.37278387f0) RGB{Float32}(0.4393427f0,0.37651044f0,0.36881092f0); RGB{Float32}(0.40786827f0,0.31765512f0,0.43138328f0) RGB{Float32}(0.4040292f0,0.32554123f0,0.43533412f0) … RGB{Float32}(0.43933928f0,0.3765122f0,0.37650484f0) RGB{Float32}(0.439345f0,0.3765228f0,0.37277195f0)]
#  [RGB{Float32}(0.9490899f0,0.9490686f0,0.9991068f0) RGB{Float32}(0.9530114f0,0.95300955f0,0.9993623f0) … RGB{Float32}(0.9848364f0,0.98486435f0,0.99542207f0) RGB{Float32}(0.9848428f0,0.98461366f0,0.9942492f0); RGB{Float32}(0.94906616f0,0.94909453f0,0.999073f0) RGB{Float32}(0.95303035f0,0.95298505f0,0.99944633f0) … RGB{Float32}(0.9844885f0,0.9846506f0,0.9960647f0) RGB{Float32}(0.98452973f0,0.9844546f0,0.9957866f0); … ; RGB{Float32}(0.9058247f0,0.90587175f0,0.90588784f0) RGB{Float32}(0.9097935f0,0.90980875f0,0.9098586f0) … RGB{Float32}(0.925436f0,0.92555845f0,0.9254216f0) RGB{Float32}(0.9215733f0,0.92168033f0,0.9215305f0); RGB{Float32}(0.90583265f0,0.90586776f0,0.9058816f0) RGB{Float32}(0.90578943f0,0.9058857f0,0.90591794f0) … RGB{Float32}(0.92153955f0,0.92162615f0,0.9216711f0) RGB{Float32}(0.92153186f0,0.9216156f0,0.9214902f0)]
#  [RGB{Float32}(0.26664647f0,0.5254635f0,0.97114795f0) RGB{Float32}(0.2705735f0,0.52938765f0,0.97166157f0) … RGB{Float32}(0.25873518f0,0.51757514f0,0.9478819f0) RGB{Float32}(0.25480306f0,0.51369065f0,0.94396573f0); RGB{Float32}(0.28235617f0,0.5254622f0,0.9750369f0) RGB{Float32}(0.28623232f0,0.5254704f0,0.9756614f0) … RGB{Float32}(0.26273316f0,0.52151644f0,0.951937f0) RGB{Float32}(0.25881055f0,0.51763135f0,0.9519023f0); … ; RGB{Float32}(0.76084167f0,0.6431549f0,0.54512453f0) RGB{Float32}(0.7569099f0,0.67061377f0,0.5725315f0) … RGB{Float32}(0.78448206f0,0.75681627f0,0.690466f0) RGB{Float32}(0.8079529f0,0.76070607f0,0.7609863f0); RGB{Float32}(0.75299287f0,0.6627607f0,0.568642f0) RGB{Float32}(0.8157772f0,0.7098257f0,0.65489554f0) … RGB{Float32}(0.7451737f0,0.6940807f0,0.60779965f0) RGB{Float32}(0.79225826f0,0.733298f0,0.6747389f0)]
